# %% [markdown]
# <h1 style="text-align: center;">GBP-LKR Currency Exchange Prediction</h1>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Original Datasets/USD_Data.csv")
df
# Out:
#             Date    Price     Open     High      Low Vol. Change %
# 0     05/09/2024  300.430  300.325  300.430  300.325  NaN    0.03%
# 1     05/08/2024  300.325  299.753  300.325  299.753  NaN    0.19%
# 2     05/07/2024  299.753  296.965  299.753  296.875  NaN    0.59%
# 3     05/06/2024  298.000  297.125  298.700  297.125  NaN    0.34%
# 4     05/03/2024  297.000  296.850  297.350  296.800  NaN    0.03%
# ...          ...      ...      ...      ...      ...  ...      ...
# 3684  01/07/2010  114.310  114.300  114.370  114.250  NaN   -0.01%
# 3685  01/06/2010  114.325  114.300  114.355  114.200  NaN    0.00%
# 3686  01/05/2010  114.325  114.280  114.395  114.250  NaN   -0.11%
# 3687  01/04/2010  114.450  114.400  114.500  114.370  NaN    0.04%
# 3688  01/01/2010  114.400  114.300  114.450  114.220  NaN    0.00%
#
# [3689 rows x 7 columns]

# %%
df.dtypes
# Out:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.         object
# Change %     object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.                object
# Change %            object
# dtype: object

# %%
df.drop(columns=['Vol.'], inplace=True)
df
# Out:
#            Date    Price     Open     High      Low Change %
# 0    2024-05-09  300.430  300.325  300.430  300.325    0.03%
# 1    2024-05-08  300.325  299.753  300.325  299.753    0.19%
# 2    2024-05-07  299.753  296.965  299.753  296.875    0.59%
# 3    2024-05-06  298.000  297.125  298.700  297.125    0.34%
# 4    2024-05-03  297.000  296.850  297.350  296.800    0.03%
# ...         ...      ...      ...      ...      ...      ...
# 3684 2010-01-07  114.310  114.300  114.370  114.250   -0.01%
# 3685 2010-01-06  114.325  114.300  114.355  114.200    0.00%
# 3686 2010-01-05  114.325  114.280  114.395  114.250   -0.11%
# 3687 2010-01-04  114.450  114.400  114.500  114.370    0.04%
# 3688 2010-01-01  114.400  114.300  114.450  114.220    0.00%
#
# [3689 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### 1. Date against Parameters

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Date"], y=df["Price"], color='hotpink')
plt.title("GBP Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Date"], y=df["Open"], color='gold')
plt.title("Variation of Open value with Date")
plt.xlabel("Date")
plt.ylabel("Open Value")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Date"], y=df["High"], color='red')
plt.title("Variation of High value with Date")
plt.xlabel("Date")
plt.ylabel("High Value")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Date"], y=df["Low"], color='purple')
plt.title("Variation of Low value with Date")
plt.xlabel("Date")
plt.ylabel("Low Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 2. Price against Parameters

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Price"], y=df["Open"], color='gold')
plt.title("Variation of Open value with Price")
plt.xlabel("Price")
plt.ylabel("Open Value")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Price"], y=df["High"], color='red')
plt.title("Variation of High value with Price")
plt.xlabel("Price")
plt.ylabel("High Value")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["Price"], y=df["Low"], color='purple')
plt.title("Variation of Low value with Price")
plt.xlabel("Price")
plt.ylabel("Low Value")
plt.show()

# %% [markdown]
# ## Model Synthesis

# %%
df.drop(columns=["Open","High","Low","Change %"], inplace=True)
df
# Out:
#            Date    Price
# 0    2024-05-09  300.430
# 1    2024-05-08  300.325
# 2    2024-05-07  299.753
# 3    2024-05-06  298.000
# 4    2024-05-03  297.000
# ...         ...      ...
# 3684 2010-01-07  114.310
# 3685 2010-01-06  114.325
# 3686 2010-01-05  114.325
# 3687 2010-01-04  114.450
# 3688 2010-01-01  114.400
#
# [3689 rows x 2 columns]

# %%
from pmdarima import auto_arima 
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# ### 1. ARIMA Model

# %%
from statsmodels.tsa.arima.model import ARIMA

train_size = int(len(df)*0.8)
train_col, test_col = df.iloc[:train_size], df.iloc[train_size:]

auto_arima_model = auto_arima(train_col['Price'], seasonal=False, trace=False)
p,d,q = auto_arima_model.order
print(p,d,q)
arima_model = ARIMA(train_col['Price'], order=(p,d,q))
arima_model = arima_model.fit()
print(arima_model.summary())
arima_model.plot_diagnostics(figsize=(10,8))
# Out:
# 4 1 0
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 2951
# Model:                 ARIMA(4, 1, 0)   Log Likelihood               -5346.328
# Date:                Thu, 09 May 2024   AIC                          10702.656
# Time:                        22:09:01   BIC                          10732.604
# Sample:                             0   HQIC                         10713.438
#                                - 2951
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1141      0.006    -19.618      0.000      -0.125      -0.103
# ar.L2          0.2100      0.004     52.386      0.000       0.202       0.218
# ar.L3          0.1687      0.005     32.459      0.000       0.158       0.179
# ar.L4         -0.0352      0.007     -4.823      0.000      -0.050      -0.021
# sigma2         2.1961      0.013    165.639      0.000       2.170       2.222
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            612217.48
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.01   Skew:                            -2.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        73.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_testing_predictions = arima_model.forecast(steps=len(test_col))
mse = mean_squared_error(test_col['Price'], arima_testing_predictions)
mae = mean_absolute_error(test_col['Price'], arima_testing_predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error for the ARIMA model is {mse}")
print(f"Mean Absolute Error for the ARIMA model is {mae}")
print(f"Root Mean Sqaured Error for the ARIMA model is {rmse}")
# Out:
# Mean Squared Error for the ARIMA model is 256.160566561117
# Mean Absolute Error for the ARIMA model is 14.351418235810895
# Root Mean Sqaured Error for the ARIMA model is 16.005016918488934

# %% [markdown]
# ### 2. SARIMAX Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

train_size = int(len(df)*0.8)
train_col, test_col = df.iloc[:train_size], df.iloc[train_size:]

print(p,d,q)
sarimax_model = SARIMAX(train_col['Price'], order=(p,d,q), seasonal_order=(p,d,q,12))
sarimax_model = sarimax_model.fit()
print(sarimax_model.summary())
sarimax_model.plot_diagnostics(figsize=(10,8))
# Out:
# 4 1 0
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Price   No. Observations:                 2951
# Model:             SARIMAX(4, 1, 0)x(4, 1, 0, 12)   Log Likelihood               -5580.456
# Date:                            Thu, 09 May 2024   AIC                          11178.911
# Time:                                    22:09:15   BIC                          11232.781
# Sample:                                         0   HQIC                         11198.309
#                                            - 2951
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1159      0.007    -15.506      0.000      -0.131      -0.101
# ar.L2          0.1746      0.005     34.762      0.000       0.165       0.184
# ar.L3          0.1670      0.007     25.103      0.000       0.154       0.180
# ar.L4         -0.0547      0.007     -7.479      0.000      -0.069      -0.040
# ar.S.L12      -0.7092      0.007   -103.328      0.000      -0.723      -0.696
# ar.S.L24      -0.5345      0.008    -65.932      0.000      -0.550      -0.519
# ar.S.L36      -0.3591      0.008    -42.627      0.000      -0.376      -0.343
# ar.S.L48      -0.1746      0.008    -22.710      0.000      -0.190      -0.160
# sigma2         2.6061      0.017    155.844      0.000       2.573       2.639
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            366787.53
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.01   Skew:                            -1.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                        57.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
sarimax_testing_predictions = sarimax_model.forecast(steps=len(test_col))
mse = mean_squared_error(test_col['Price'], sarimax_testing_predictions)
mae = mean_absolute_error(test_col['Price'], sarimax_testing_predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error for the SARIMAX model is {mse}")
print(f"Mean Absolute Error for the SARIMAX model is {mae}")
print(f"Root Mean Sqaured Error for the SARIMAX model is {rmse}")
# Out:
# Mean Squared Error for the SARIMAX model is 1527.0368661792131
# Mean Absolute Error for the SARIMAX model is 34.61058973893833
# Root Mean Sqaured Error for the SARIMAX model is 39.0773190761497

# %% [markdown]
# ### 3. LSTM Model

# %%
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
    return np.array(sequences)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

scaler = MinMaxScaler(feature_range=(0,1))
df["Price"] = scaler.fit_transform(df["Price"].values.reshape(-1, 1))

train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]

sequence_length = 10
x_train = create_sequences(train['Price'], sequence_length)
x_test = create_sequences(test['Price'], sequence_length)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

lstm_model = Sequential()
lstm_model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(units=1))

print(lstm_model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,651 (119.73 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# training the model
lstm_model.fit(x_train, train['Price'][sequence_length:], epochs=100, batch_size=32)

# evaluating the model
loss = lstm_model.evaluate(x_test, test['Price'][sequence_length:])

# predicting the values
lstm_predictions = lstm_model.predict(x_test)

# getting the actual values using inverse transformation
lstm_predictions_actual = scaler.inverse_transform(lstm_predictions)

lstm_actual_vals = scaler.inverse_transform(test["Price"][sequence_length:].values.reshape(-1, 1))

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(lstm_actual_vals, lstm_predictions_actual)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(lstm_actual_vals, lstm_predictions_actual)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print(f"Mean Absolute Error for LSTM model is {mae}")
print(f"Mean Squared Error for LSTM model is {mse}")
print(f"Root Mean Squared Error for LSTM model is {rmse}")
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0356
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0012
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0011
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.8549e-04
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0012
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0011
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.6130e-04
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0010
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.8236e-04
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.6283e-04
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8606e-04
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3791e-04
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1178e-04
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4342e-04
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6086e-04
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2179e-04
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4856e-04
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8326e-04
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.4884e-04
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4066e-04
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6340e-04
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8768e-04
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6018e-04
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3361e-04
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.4421e-04
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1576e-04
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6552e-04
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2985e-04
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9354e-04
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5676e-04
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7384e-04
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9029e-04
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9337e-04
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9912e-04
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3397e-04
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7062e-04
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9884e-04
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.0259e-04
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6521e-04
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.5999e-04
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4965e-04
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5868e-04
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2276e-04
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8968e-04
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0296e-04
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9426e-04
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4829e-04
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1923e-04
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9237e-04
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7076e-04
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3452e-04
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4372e-04
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5389e-04
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0591e-04
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0254e-04
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5745e-04
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7368e-04
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1573e-04
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6840e-04
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8892e-04
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5899e-04
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1182e-04
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6580e-04
# Epoch 74/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4005e-04
# Epoch 75/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5256e-04
# Epoch 76/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6070e-04
# Epoch 77/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.1843e-04
# Epoch 78/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0297e-04
# Epoch 79/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4651e-04
# Epoch 80/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6910e-04
# Epoch 81/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2022e-04
# Epoch 82/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.6390e-04
# Epoch 83/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.4716e-04
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.8027e-04
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.4592e-04
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.0424e-04
# Epoch 87/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.7383e-04
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7206e-04
# Epoch 89/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4430e-04
# Epoch 90/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.9965e-04
# Epoch 91/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9584e-04
# Epoch 92/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.2948e-04
# Epoch 93/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.0772e-04
# Epoch 94/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4472e-04
# Epoch 95/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3550e-04
# Epoch 96/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5136e-04
# Epoch 97/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7057e-04
# Epoch 98/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.4925e-04
# Epoch 99/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.3924e-04
# Epoch 100/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2257e-04
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7971e-05
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Mean Absolute Error for LSTM model is 1.3391119996793974
# Mean Squared Error for LSTM model is 2.009966057278086
# Root Mean Squared Error for LSTM model is 1.417732717150199

# %%
# plotting actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(lstm_actual_vals, label='Actual Values')
plt.plot(lstm_predictions_actual, label='Predicted Values')
plt.title('Actual vs Predicted Exchange Rates')
plt.xlabel("Date")
plt.ylabel("Exchange rate")
plt.legend()
plt.show()

# %% [markdown]
# ### Saving the best model

# %%
import os
directory = "Models"

if not os.path.exists(directory):
    os.makedirs(directory)
lstm_model.save("Models/GBP_Model.keras")

# %% [markdown]
# ## Analysis

# %% [markdown]
# By evaluating the evaluation metrics for each model, we can identify that the predictions are very close to the actual values in the LSTM model. Thus we can say that this could be the best model out of the three.
